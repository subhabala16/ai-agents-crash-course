# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-dense: potassium, fiber, vitamins; natural sugars but moderate.
# 2) Lollipop: 2/10 - Mostly sugar, little to no nutrients; empty calories.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# I’m missing the two foods to compare. Please specify the items (e.g., apples vs oranges vs almonds), and I’ll rank them 1–10 with brief notes. If you want apples included in an existing pair, tell me the other food already being compared.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Bananas are healthier.
#
# 1) Bananas: 8/10 - Nutrient-dense: potassium, fiber, vitamin C, natural sugars; low in fat.
# 2) Lollipop: 2/10 - Mostly added sugar with little to no nutrients; easy to overconsume.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-dense: potassium, fiber, vitamin C; natural sugars but balanced with nutrients.
# 2) Apples: 7/10 - Fiber-rich, vitamin C, polyphenols; lower calories and fat, but still sugars.
# 3) Lollipop: 2/10 - Mostly added sugar with few nutrients.

# %%
with trace("Nutrition Agent"):
    result = await Runner.run(
      nutrition_agent, "Add mango to comparison", session=session
    )
    print(result.final_output)
# Out:
# Mango is already included. Here’s the current list:
#
# 1) Bananas: 8/10 - Nutrient-dense: potassium, fiber, vitamin C; natural sugars but balanced nutrients.
# 2) Mango: 7/10 - Vitamins A and C, fiber; higher natural sugars but nutrient-dense.
# 3) Apples: 7/10 - Fiber-rich, vitamin C, polyphenols; lower calories and fat, but natural sugars.
# 4) Lollipop: 2/10 - Mostly added sugar with few nutrients.
